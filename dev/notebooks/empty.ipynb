# %%
# Random function example
import random
import platform

def get_random_number():
    return random.randint(1, 100)

print(get_random_number())
print(platform.node())
# Out:
# 87
# runtime-01kc3s0cq7tqs81cdxyph0be09
